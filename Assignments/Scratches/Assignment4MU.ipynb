# %% [markdown]
# <a href="https://colab.research.google.com/github/brunofbpaula/DataScience-UM-Coursera/blob/main/Assignments/Scratches/Assignment4MU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

# %% [markdown]
# ## Question One

# %%
nhl_df=pd.read_csv("assets/nhl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

# %%
nhl_df
# Out:
#                      team                 GP                  W  \
# 0       Atlantic Division  Atlantic Division  Atlantic Division
# 1    Tampa Bay Lightning*                 82                 54
# 2          Boston Bruins*                 82                 50
# 3    Toronto Maple Leafs*                 82                 49
# 4        Florida Panthers                 82                 44
# ..                    ...                ...                ...
# 166    Los Angeles Kings*                 82                 46
# 167       Phoenix Coyotes                 82                 37
# 168     Vancouver Canucks                 82                 36
# 169        Calgary Flames                 82                 35
# 170       Edmonton Oilers                 82                 29
#
#                      L                 OL                PTS  \
# 0    Atlantic Division  Atlantic Division  Atlantic Division
# 1                   23                  5                113
# 2                   20                 12                112
# 3                   26                  7                105
# 4                   30                  8                 96
# ..                 ...                ...                ...
# 166                 28                  8                100
# 167                 30                 15                 89
# 168                 35                 11                 83
# 169                 40                  7                 77
# 170                 44                  9                 67
#
#                   PTS%                 GF                 GA  \
# 0    Atlantic Division  Atlantic Division  Atlantic Division
# 1                 .689                296                236
# 2                 .683                270                214
# 3                 .640                277                232
# 4                 .585                248                246
# ..                 ...                ...                ...
# 166               .610                206                174
# 167               .543                216                231
# 168               .506                196                223
# 169               .470                209                241
# 170               .409                203                270
#
#                    SRS                SOS               RPt%  \
# 0    Atlantic Division  Atlantic Division  Atlantic Division
# 1                 0.66              -0.07               .634
# 2                 0.62              -0.07               .610
# 3                 0.49              -0.06               .567
# 4                -0.01              -0.04               .537
# ..                 ...                ...                ...
# 166               0.40               0.01               .549
# 167              -0.16               0.03               .457
# 168              -0.30               0.03               .451
# 169              -0.35               0.04               .402
# 170              -0.75               0.07               .348
#
#                    ROW  year League
# 0    Atlantic Division  2018    NHL
# 1                   48  2018    NHL
# 2                   47  2018    NHL
# 3                   42  2018    NHL
# 4                   41  2018    NHL
# ..                 ...   ...    ...
# 166                 38  2014    NHL
# 167                 31  2014    NHL
# 168                 31  2014    NHL
# 169                 28  2014    NHL
# 170                 25  2014    NHL
#
# [171 rows x 15 columns]

# %%
cities
# Out:
#          Metropolitan area Population (2016 est.)[8]                    NFL  \
# 0            New York City                  20153634    Giants Jets[note 1]
# 1              Los Angeles                  13310447  Rams Chargers[note 4]
# 2   San Francisco Bay Area                   6657982  49ers Raiders[note 6]
# 3                  Chicago                   9512999          Bears[note 8]
# 4        Dallas–Fort Worth                   7233323                Cowboys
# 5         Washington, D.C.                   6131977               Redskins
# 6             Philadelphia                   6070500                 Eagles
# 7                   Boston                   4794447      Patriots[note 14]
# 8   Minneapolis–Saint Paul                   3551036                Vikings
# 9                   Denver                   2853077                Broncos
# 10   Miami–Fort Lauderdale                   6066387               Dolphins
# 11                 Phoenix                   4661537              Cardinals
# 12                 Detroit                   4297617                  Lions
# 13                 Toronto                   5928040            — [note 22]
# 14                 Houston                   6772470        Texans[note 24]
# 15                 Atlanta                   5789700                Falcons
# 16          Tampa Bay Area                   3032171             Buccaneers
# 17              Pittsburgh                   2342299               Steelers
# 18               Cleveland                   2055612        Browns[note 29]
# 19                 Seattle                   3798902               Seahawks
# 20              Cincinnati                   2165139                Bengals
# 21             Kansas City                   2104509                 Chiefs
# 22               St. Louis                   2807002              [note 40]
# 23               Baltimore                   2798886        Ravens[note 45]
# 24               Charlotte                   2474314               Panthers
# 25            Indianapolis                   2004230                  Colts
# 26               Nashville                   1865298                 Titans
# 27               Milwaukee                   1572482              [note 53]
# 28             New Orleans                   1268883                 Saints
# 29                 Buffalo                   1132804         Bills[note 56]
# 30                Montreal                   4098927                      —
# 31               Vancouver                   2463431                      —
# 32                 Orlando                   2441257                      —
# 33                Portland                   2424955                      —
# 34                Columbus                   2041520                      —
# 35                 Calgary                   1392609                      —
# 36                  Ottawa                   1323783                      —
# 37                Edmonton                   1321426                      —
# 38          Salt Lake City                   1186187                      —
# 39                Winnipeg                    778489                      —
# 40               San Diego                   3317749              [note 62]
# 41             San Antonio                   2429609              [note 64]
# 42              Sacramento                   2296418                      —
# 43               Las Vegas                   2155664               [note 6]
# 44            Jacksonville                   1478212                Jaguars
# 45           Oklahoma City                   1373211                      —
# 46                 Memphis                   1342842              [note 69]
# 47                 Raleigh                   1302946                      —
# 48               Green Bay                    318236                Packers
# 49                Hamilton                    747545                      —
# 50                  Regina                    236481                      —
#
#                      MLB                 NBA                               NHL
# 0   Yankees Mets[note 2]         Knicks Nets  Rangers Islanders Devils[note 3]
# 1         Dodgers Angels     Lakers Clippers                       Kings Ducks
# 2       Giants Athletics            Warriors                    Sharks[note 7]
# 3         Cubs White Sox       Bulls[note 9]                        Blackhawks
# 4                Rangers           Mavericks                             Stars
# 5     Nationals[note 10]    Wizards[note 11]                          Capitals
# 6      Phillies[note 12]               76ers                   Flyers[note 13]
# 7       Red Sox[note 15]             Celtics                            Bruins
# 8                  Twins        Timberwolves                     Wild[note 16]
# 9                Rockies    Nuggets[note 17]                Avalanche[note 18]
# 10               Marlins                Heat                          Panthers
# 11          Diamondbacks                Suns                           Coyotes
# 12       Tigers[note 20]    Pistons[note 21]                         Red Wings
# 13             Blue Jays    Raptors[note 23]                       Maple Leafs
# 14                Astros             Rockets                                 —
# 15                Braves               Hawks                         [note 25]
# 16                  Rays                   —                         Lightning
# 17               Pirates           [note 27]                 Penguins[note 28]
# 18      Indians[note 30]  Cavaliers[note 31]                         [note 32]
# 19              Mariners           [note 33]                         [note 34]
# 20         Reds[note 35]           [note 36]                                 —
# 21       Royals[note 37]           [note 38]                         [note 39]
# 22    Cardinals[note 41]           [note 42]                    Blues[note 43]
# 23      Orioles[note 46]           [note 47]                                 —
# 24                     —    Hornets[note 49]                                 —
# 25             [note 50]     Pacers[note 51]                                 —
# 26                     —                   —                         Predators
# 27      Brewers[note 54]               Bucks                                 —
# 28                     —   Pelicans[note 55]                                 —
# 29             [note 57]           [note 58]                            Sabres
# 30             [note 59]                   —                         Canadiens
# 31                     —           [note 60]                           Canucks
# 32                     —               Magic                                 —
# 33                     —       Trail Blazers                                 —
# 34                     —                   —                      Blue Jackets
# 35                     —                   —                            Flames
# 36                     —                   —                          Senators
# 37                     —                   —                            Oilers
# 38                     —                Jazz                                 —
# 39                     —                   —                     Jets[note 61]
# 40                Padres           [note 63]                                 —
# 41                     —               Spurs                                 —
# 42                     —               Kings                                 —
# 43                     —                   —                    Golden Knights
# 44                     —                   —                                 —
# 45                     —    Thunder[note 68]                                 —
# 46                     —           Grizzlies                                 —
# 47                     —                   —                        Hurricanes
# 48                     —                   —                                 —
# 49                     —                   —                         [note 71]
# 50                     —                   —                                 —

# %%
# Keeping only columns of interest
nhl_2018 = nhl_df[nhl_df.year == 2018]
nhl_2018 = nhl_2018[['team', 'W', 'L', 'year']]
nhl_2018
# Out:
#                       team                      W                      L  year
# 0        Atlantic Division      Atlantic Division      Atlantic Division  2018
# 1     Tampa Bay Lightning*                     54                     23  2018
# 2           Boston Bruins*                     50                     20  2018
# 3     Toronto Maple Leafs*                     49                     26  2018
# 4         Florida Panthers                     44                     30  2018
# 5        Detroit Red Wings                     30                     39  2018
# 6       Montreal Canadiens                     29                     40  2018
# 7          Ottawa Senators                     28                     43  2018
# 8           Buffalo Sabres                     25                     45  2018
# 9    Metropolitan Division  Metropolitan Division  Metropolitan Division  2018
# 10    Washington Capitals*                     49                     26  2018
# 11    Pittsburgh Penguins*                     47                     29  2018
# 12    Philadelphia Flyers*                     42                     26  2018
# 13  Columbus Blue Jackets*                     45                     30  2018
# 14      New Jersey Devils*                     44                     29  2018
# 15     Carolina Hurricanes                     36                     35  2018
# 16      New York Islanders                     35                     37  2018
# 17        New York Rangers                     34                     39  2018
# 18        Central Division       Central Division       Central Division  2018
# 19    Nashville Predators*                     53                     18  2018
# 20          Winnipeg Jets*                     52                     20  2018
# 21         Minnesota Wild*                     45                     26  2018
# 22     Colorado Avalanche*                     43                     30  2018
# 23         St. Louis Blues                     44                     32  2018
# 24            Dallas Stars                     42                     32  2018
# 25      Chicago Blackhawks                     33                     39  2018
# 26        Pacific Division       Pacific Division       Pacific Division  2018
# 27   Vegas Golden Knights*                     51                     24  2018
# 28          Anaheim Ducks*                     44                     25  2018
# 29        San Jose Sharks*                     45                     27  2018
# 30      Los Angeles Kings*                     45                     29  2018
# 31          Calgary Flames                     37                     35  2018
# 32         Edmonton Oilers                     36                     40  2018
# 33       Vancouver Canucks                     31                     40  2018
# 34         Arizona Coyotes                     29                     41  2018

# %%
# Cleaning teams' names in NHL DataFrame
def clean_team(item):
  if item[-1] == '*':
    item= item[:-1]
    return item
  return item

nhl_2018['team'] = nhl_2018.team.apply(clean_team)
nhl_2018
# Out:
#                      team                      W                      L  year
# 0       Atlantic Division      Atlantic Division      Atlantic Division  2018
# 1     Tampa Bay Lightning                     54                     23  2018
# 2           Boston Bruins                     50                     20  2018
# 3     Toronto Maple Leafs                     49                     26  2018
# 4        Florida Panthers                     44                     30  2018
# 5       Detroit Red Wings                     30                     39  2018
# 6      Montreal Canadiens                     29                     40  2018
# 7         Ottawa Senators                     28                     43  2018
# 8          Buffalo Sabres                     25                     45  2018
# 9   Metropolitan Division  Metropolitan Division  Metropolitan Division  2018
# 10    Washington Capitals                     49                     26  2018
# 11    Pittsburgh Penguins                     47                     29  2018
# 12    Philadelphia Flyers                     42                     26  2018
# 13  Columbus Blue Jackets                     45                     30  2018
# 14      New Jersey Devils                     44                     29  2018
# 15    Carolina Hurricanes                     36                     35  2018
# 16     New York Islanders                     35                     37  2018
# 17       New York Rangers                     34                     39  2018
# 18       Central Division       Central Division       Central Division  2018
# 19    Nashville Predators                     53                     18  2018
# 20          Winnipeg Jets                     52                     20  2018
# 21         Minnesota Wild                     45                     26  2018
# 22     Colorado Avalanche                     43                     30  2018
# 23        St. Louis Blues                     44                     32  2018
# 24           Dallas Stars                     42                     32  2018
# 25     Chicago Blackhawks                     33                     39  2018
# 26       Pacific Division       Pacific Division       Pacific Division  2018
# 27   Vegas Golden Knights                     51                     24  2018
# 28          Anaheim Ducks                     44                     25  2018
# 29        San Jose Sharks                     45                     27  2018
# 30      Los Angeles Kings                     45                     29  2018
# 31         Calgary Flames                     37                     35  2018
# 32        Edmonton Oilers                     36                     40  2018
# 33      Vancouver Canucks                     31                     40  2018
# 34        Arizona Coyotes                     29                     41  2018

# %%
# Separating columns of interest in cities DataFrame
cities.rename(columns={'Population (2016 est.)[8]': 'Population Estimate 2016'}, inplace=True)
cities = cities[['Metropolitan area', 'Population Estimate 2016', 'NHL']]

cities.head()
# Out:
#         Metropolitan area Population Estimate 2016  \
# 0           New York City                 20153634
# 1             Los Angeles                 13310447
# 2  San Francisco Bay Area                  6657982
# 3                 Chicago                  9512999
# 4       Dallas–Fort Worth                  7233323
#
#                                 NHL
# 0  Rangers Islanders Devils[note 3]
# 1                       Kings Ducks
# 2                    Sharks[note 7]
# 3                        Blackhawks
# 4                             Stars

# %%
# Cleaning teams' names in cities DataFrame
def clean_city(item):
  if '[' in item:
    return re.findall('([\w\s]*)\[', item)[0]
  return item


cities['NHL'] = cities.NHL.apply(clean_city)
cities
# Out:
# <ipython-input-76-f7e6532247d9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities['NHL'] = cities.NHL.apply(clean_city)
#          Metropolitan area Population Estimate 2016                       NHL
# 0            New York City                 20153634  Rangers Islanders Devils
# 1              Los Angeles                 13310447               Kings Ducks
# 2   San Francisco Bay Area                  6657982                    Sharks
# 3                  Chicago                  9512999                Blackhawks
# 4        Dallas–Fort Worth                  7233323                     Stars
# 5         Washington, D.C.                  6131977                  Capitals
# 6             Philadelphia                  6070500                    Flyers
# 7                   Boston                  4794447                    Bruins
# 8   Minneapolis–Saint Paul                  3551036                      Wild
# 9                   Denver                  2853077                 Avalanche
# 10   Miami–Fort Lauderdale                  6066387                  Panthers
# 11                 Phoenix                  4661537                   Coyotes
# 12                 Detroit                  4297617                 Red Wings
# 13                 Toronto                  5928040               Maple Leafs
# 14                 Houston                  6772470                         —
# 15                 Atlanta                  5789700
# 16          Tampa Bay Area                  3032171                 Lightning
# 17              Pittsburgh                  2342299                  Penguins
# 18               Cleveland                  2055612
# 19                 Seattle                  3798902
# 20              Cincinnati                  2165139                         —
# 21             Kansas City                  2104509
# 22               St. Louis                  2807002                     Blues
# 23               Baltimore                  2798886                         —
# 24               Charlotte                  2474314                         —
# 25            Indianapolis                  2004230                         —
# 26               Nashville                  1865298                 Predators
# 27               Milwaukee                  1572482                         —
# 28             New Orleans                  1268883                         —
# 29                 Buffalo                  1132804                    Sabres
# 30                Montreal                  4098927                 Canadiens
# 31               Vancouver                  2463431                   Canucks
# 32                 Orlando                  2441257                         —
# 33                Portland                  2424955                         —
# 34                Columbus                  2041520              Blue Jackets
# 35                 Calgary                  1392609                    Flames
# 36                  Ottawa                  1323783                  Senators
# 37                Edmonton                  1321426                    Oilers
# 38          Salt Lake City                  1186187                         —
# 39                Winnipeg                   778489                      Jets
# 40               San Diego                  3317749                         —
# 41             San Antonio                  2429609                         —
# 42              Sacramento                  2296418                         —
# 43               Las Vegas                  2155664            Golden Knights
# 44            Jacksonville                  1478212                         —
# 45           Oklahoma City                  1373211                         —
# 46                 Memphis                  1342842                         —
# 47                 Raleigh                  1302946                Hurricanes
# 48               Green Bay                   318236                         —
# 49                Hamilton                   747545
# 50                  Regina                   236481                         —

# %%
# Removing divisions from NHL DataFrame
nhl_2018 = nhl_2018[~nhl_2018.W.str.contains('Division')]
nhl_2018
# Out:
#                      team   W   L  year
# 1     Tampa Bay Lightning  54  23  2018
# 2           Boston Bruins  50  20  2018
# 3     Toronto Maple Leafs  49  26  2018
# 4        Florida Panthers  44  30  2018
# 5       Detroit Red Wings  30  39  2018
# 6      Montreal Canadiens  29  40  2018
# 7         Ottawa Senators  28  43  2018
# 8          Buffalo Sabres  25  45  2018
# 10    Washington Capitals  49  26  2018
# 11    Pittsburgh Penguins  47  29  2018
# 12    Philadelphia Flyers  42  26  2018
# 13  Columbus Blue Jackets  45  30  2018
# 14      New Jersey Devils  44  29  2018
# 15    Carolina Hurricanes  36  35  2018
# 16     New York Islanders  35  37  2018
# 17       New York Rangers  34  39  2018
# 19    Nashville Predators  53  18  2018
# 20          Winnipeg Jets  52  20  2018
# 21         Minnesota Wild  45  26  2018
# 22     Colorado Avalanche  43  30  2018
# 23        St. Louis Blues  44  32  2018
# 24           Dallas Stars  42  32  2018
# 25     Chicago Blackhawks  33  39  2018
# 27   Vegas Golden Knights  51  24  2018
# 28          Anaheim Ducks  44  25  2018
# 29        San Jose Sharks  45  27  2018
# 30      Los Angeles Kings  45  29  2018
# 31         Calgary Flames  37  35  2018
# 32        Edmonton Oilers  36  40  2018
# 33      Vancouver Canucks  31  40  2018
# 34        Arizona Coyotes  29  41  2018

# %%
# Separate team's names from cities' names
nhl_2018['team'] = nhl_2018.team.apply(lambda y: y.rsplit(None, 1)[-1])
nhl_2018.loc[3, 'team'] = 'Maple Leafs'
nhl_2018.loc[5, 'team'] = 'Red Wings'
nhl_2018.loc[13, 'team'] = 'Blue Jackets'
nhl_2018.loc[27, 'team'] = 'Golden Knights'

nhl_2018
# Out:
# <ipython-input-78-3bc676a87028>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhl_2018['team'] = nhl_2018.team.apply(lambda y: y.rsplit(None, 1)[-1])
#               team   W   L  year
# 1        Lightning  54  23  2018
# 2           Bruins  50  20  2018
# 3      Maple Leafs  49  26  2018
# 4         Panthers  44  30  2018
# 5        Red Wings  30  39  2018
# 6        Canadiens  29  40  2018
# 7         Senators  28  43  2018
# 8           Sabres  25  45  2018
# 10        Capitals  49  26  2018
# 11        Penguins  47  29  2018
# 12          Flyers  42  26  2018
# 13    Blue Jackets  45  30  2018
# 14          Devils  44  29  2018
# 15      Hurricanes  36  35  2018
# 16       Islanders  35  37  2018
# 17         Rangers  34  39  2018
# 19       Predators  53  18  2018
# 20            Jets  52  20  2018
# 21            Wild  45  26  2018
# 22       Avalanche  43  30  2018
# 23           Blues  44  32  2018
# 24           Stars  42  32  2018
# 25      Blackhawks  33  39  2018
# 27  Golden Knights  51  24  2018
# 28           Ducks  44  25  2018
# 29          Sharks  45  27  2018
# 30           Kings  45  29  2018
# 31          Flames  37  35  2018
# 32          Oilers  36  40  2018
# 33         Canucks  31  40  2018
# 34         Coyotes  29  41  2018

# %%
# Replacing names of teams from the same city
nhl_2018.loc[14, 'team'] = 'Rangers Islanders Devils'
nhl_2018.loc[16, 'team'] = 'Rangers Islanders Devils'
nhl_2018.loc[17, 'team'] = 'Rangers Islanders Devils'
nhl_2018.loc[28, 'team'] = 'Kings Ducks'
nhl_2018.loc[30, 'team'] = 'Kings Ducks'

nhl_2018
# Out:
#                         team   W   L  year
# 1                  Lightning  54  23  2018
# 2                     Bruins  50  20  2018
# 3                Maple Leafs  49  26  2018
# 4                   Panthers  44  30  2018
# 5                  Red Wings  30  39  2018
# 6                  Canadiens  29  40  2018
# 7                   Senators  28  43  2018
# 8                     Sabres  25  45  2018
# 10                  Capitals  49  26  2018
# 11                  Penguins  47  29  2018
# 12                    Flyers  42  26  2018
# 13              Blue Jackets  45  30  2018
# 14  Rangers Islanders Devils  44  29  2018
# 15                Hurricanes  36  35  2018
# 16  Rangers Islanders Devils  35  37  2018
# 17  Rangers Islanders Devils  34  39  2018
# 19                 Predators  53  18  2018
# 20                      Jets  52  20  2018
# 21                      Wild  45  26  2018
# 22                 Avalanche  43  30  2018
# 23                     Blues  44  32  2018
# 24                     Stars  42  32  2018
# 25                Blackhawks  33  39  2018
# 27            Golden Knights  51  24  2018
# 28               Kings Ducks  44  25  2018
# 29                    Sharks  45  27  2018
# 30               Kings Ducks  45  29  2018
# 31                    Flames  37  35  2018
# 32                    Oilers  36  40  2018
# 33                   Canucks  31  40  2018
# 34                   Coyotes  29  41  2018

# %%
# Asserting datatypes
nhl_2018.W = nhl_2018.W.astype(float)
nhl_2018.L = nhl_2018.L.astype(float)

# Grouping by teams with same name and getting ther average W and L values
nhl_2018 = nhl_2018.groupby(by='team')['W', 'L'].mean()
nhl_2018.reset_index(inplace=True)
nhl_2018
# Out:
# <ipython-input-80-348dd27c6131>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhl_2018.W = nhl_2018.W.astype(float)
# <ipython-input-80-348dd27c6131>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nhl_2018.L = nhl_2018.L.astype(float)
# <ipython-input-80-348dd27c6131>:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   nhl_2018 = nhl_2018.groupby(by='team')['W', 'L'].mean()
#                         team          W     L
# 0                  Avalanche  43.000000  30.0
# 1                 Blackhawks  33.000000  39.0
# 2               Blue Jackets  45.000000  30.0
# 3                      Blues  44.000000  32.0
# 4                     Bruins  50.000000  20.0
# 5                  Canadiens  29.000000  40.0
# 6                    Canucks  31.000000  40.0
# 7                   Capitals  49.000000  26.0
# 8                    Coyotes  29.000000  41.0
# 9                     Flames  37.000000  35.0
# 10                    Flyers  42.000000  26.0
# 11            Golden Knights  51.000000  24.0
# 12                Hurricanes  36.000000  35.0
# 13                      Jets  52.000000  20.0
# 14               Kings Ducks  44.500000  27.0
# 15                 Lightning  54.000000  23.0
# 16               Maple Leafs  49.000000  26.0
# 17                    Oilers  36.000000  40.0
# 18                  Panthers  44.000000  30.0
# 19                  Penguins  47.000000  29.0
# 20                 Predators  53.000000  18.0
# 21  Rangers Islanders Devils  37.666667  35.0
# 22                 Red Wings  30.000000  39.0
# 23                    Sabres  25.000000  45.0
# 24                  Senators  28.000000  43.0
# 25                    Sharks  45.000000  27.0
# 26                     Stars  42.000000  32.0
# 27                      Wild  45.000000  26.0

# %%
# Merging DataFrames
cities.rename(columns={'NHL': 'team'}, inplace=True)
merged = pd.merge(nhl_2018, cities, how='inner', on='team')
merged
# Out:
# <ipython-input-67-aee06d353723>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities.rename(columns={'NHL': 'team'}, inplace=True)
#               team     W     L       Metropolitan area  \
# 0        Avalanche  43.0  30.0                  Denver
# 1       Blackhawks  33.0  39.0                 Chicago
# 2     Blue Jackets  45.0  30.0                Columbus
# 3            Blues  44.0  32.0               St. Louis
# 4           Bruins  50.0  20.0                  Boston
# 5        Canadiens  29.0  40.0                Montreal
# 6          Canucks  31.0  40.0               Vancouver
# 7         Capitals  49.0  26.0        Washington, D.C.
# 8          Coyotes  29.0  41.0                 Phoenix
# 9           Flames  37.0  35.0                 Calgary
# 10          Flyers  42.0  26.0            Philadelphia
# 11  Golden Knights  51.0  24.0               Las Vegas
# 12      Hurricanes  36.0  35.0                 Raleigh
# 13            Jets  52.0  20.0                Winnipeg
# 14     Kings Ducks  44.5  27.0             Los Angeles
# 15       Lightning  54.0  23.0          Tampa Bay Area
# 16     Maple Leafs  49.0  26.0                 Toronto
# 17          Oilers  36.0  40.0                Edmonton
# 18        Panthers  44.0  30.0   Miami–Fort Lauderdale
# 19        Penguins  47.0  29.0              Pittsburgh
# 20       Predators  53.0  18.0               Nashville
# 21       Red Wings  30.0  39.0                 Detroit
# 22          Sabres  25.0  45.0                 Buffalo
# 23        Senators  28.0  43.0                  Ottawa
# 24          Sharks  45.0  27.0  San Francisco Bay Area
# 25           Stars  42.0  32.0       Dallas–Fort Worth
# 26            Wild  45.0  26.0  Minneapolis–Saint Paul
#
#    Population Estimate 2016
# 0                   2853077
# 1                   9512999
# 2                   2041520
# 3                   2807002
# 4                   4794447
# 5                   4098927
# 6                   2463431
# 7                   6131977
# 8                   4661537
# 9                   1392609
# 10                  6070500
# 11                  2155664
# 12                  1302946
# 13                   778489
# 14                 13310447
# 15                  3032171
# 16                  5928040
# 17                  1321426
# 18                  6066387
# 19                  2342299
# 20                  1865298
# 21                  4297617
# 22                  1132804
# 23                  1323783
# 24                  6657982
# 25                  7233323
# 26                  3551036

# %%
# Creating Win/Loss ratio column
merged['Win/Loss Ratio'] = merged.W / (merged.W + merged.L)
merged
# Out:
#               team     W     L       Metropolitan area  \
# 0        Avalanche  43.0  30.0                  Denver
# 1       Blackhawks  33.0  39.0                 Chicago
# 2     Blue Jackets  45.0  30.0                Columbus
# 3            Blues  44.0  32.0               St. Louis
# 4           Bruins  50.0  20.0                  Boston
# 5        Canadiens  29.0  40.0                Montreal
# 6          Canucks  31.0  40.0               Vancouver
# 7         Capitals  49.0  26.0        Washington, D.C.
# 8          Coyotes  29.0  41.0                 Phoenix
# 9           Flames  37.0  35.0                 Calgary
# 10          Flyers  42.0  26.0            Philadelphia
# 11  Golden Knights  51.0  24.0               Las Vegas
# 12      Hurricanes  36.0  35.0                 Raleigh
# 13            Jets  52.0  20.0                Winnipeg
# 14     Kings Ducks  44.5  27.0             Los Angeles
# 15       Lightning  54.0  23.0          Tampa Bay Area
# 16     Maple Leafs  49.0  26.0                 Toronto
# 17          Oilers  36.0  40.0                Edmonton
# 18        Panthers  44.0  30.0   Miami–Fort Lauderdale
# 19        Penguins  47.0  29.0              Pittsburgh
# 20       Predators  53.0  18.0               Nashville
# 21       Red Wings  30.0  39.0                 Detroit
# 22          Sabres  25.0  45.0                 Buffalo
# 23        Senators  28.0  43.0                  Ottawa
# 24          Sharks  45.0  27.0  San Francisco Bay Area
# 25           Stars  42.0  32.0       Dallas–Fort Worth
# 26            Wild  45.0  26.0  Minneapolis–Saint Paul
#
#    Population Estimate 2016  Win/Loss Ratio
# 0                   2853077        0.589041
# 1                   9512999        0.458333
# 2                   2041520        0.600000
# 3                   2807002        0.578947
# 4                   4794447        0.714286
# 5                   4098927        0.420290
# 6                   2463431        0.436620
# 7                   6131977        0.653333
# 8                   4661537        0.414286
# 9                   1392609        0.513889
# 10                  6070500        0.617647
# 11                  2155664        0.680000
# 12                  1302946        0.507042
# 13                   778489        0.722222
# 14                 13310447        0.622378
# 15                  3032171        0.701299
# 16                  5928040        0.653333
# 17                  1321426        0.473684
# 18                  6066387        0.594595
# 19                  2342299        0.618421
# 20                  1865298        0.746479
# 21                  4297617        0.434783
# 22                  1132804        0.357143
# 23                  1323783        0.394366
# 24                  6657982        0.625000
# 25                  7233323        0.567568
# 26                  3551036        0.633803

# %%
# Passing in the numeric values of population_by_region and win_loss_by_region
population_by_region = pd.to_numeric(merged['Population Estimate 2016'], errors='coerce')
win_loss_by_region = pd.to_numeric(merged['Win/Loss Ratio'], errors='coerce')

answer = stats.pearsonr(population_by_region, win_loss_by_region)

# %%
answer
# Out:
# PearsonRResult(statistic=0.10909409644001987, pvalue=0.5880477982251616)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re



def nhl_correlation():

    nhl_df=pd.read_csv("assets/nhl.csv")
    cities=pd.read_html("assets/wikipedia_data.html")[1]
    cities=cities.iloc[:-1,[0,3,5,6,7,8]]

    # Keeping only columns of interest
    nhl_2018 = nhl_df[nhl_df.year == 2018]
    nhl_2018 = nhl_2018[['team', 'W', 'L', 'year']]

    # Cleaning teams' names in NHL DataFrame
    def clean_team(item):
      if item[-1] == '*':
        item= item[:-1]
        return item
      return item

    # Separating columns of interest in cities DataFrame
    cities.rename(columns={'Population (2016 est.)[8]': 'Population Estimate 2016'}, inplace=True)
    cities = cities[['Metropolitan area', 'Population Estimate 2016', 'NHL']]
    nhl_2018['team'] = nhl_2018.team.apply(clean_team)

    # Cleaning teams' names in cities DataFrame
    def clean_city(item):
      if '[' in item:
        return re.findall('([\w\s]*)\[', item)[0]
      return item
    cities['NHL'] = cities.NHL.apply(clean_city)

    # Removing divisions from NHL DataFrame
    nhl_2018 = nhl_2018[~nhl_2018.W.str.contains('Division')]

    # Separate team's names from cities' names
    nhl_2018['team'] = nhl_2018.team.apply(lambda y: y.rsplit(None, 1)[-1])
    nhl_2018.loc[3, 'team'] = 'Maple Leafs'
    nhl_2018.loc[5, 'team'] = 'Red Wings'
    nhl_2018.loc[13, 'team'] = 'Blue Jackets'
    nhl_2018.loc[27, 'team'] = 'Golden Knights'

    # Replacing names of teams from the same city
    nhl_2018.loc[14, 'team'] = 'Rangers Islanders Devils'
    nhl_2018.loc[16, 'team'] = 'Rangers Islanders Devils'
    nhl_2018.loc[17, 'team'] = 'Rangers Islanders Devils'
    nhl_2018.loc[28, 'team'] = 'Kings Ducks'
    nhl_2018.loc[30, 'team'] = 'Kings Ducks'

    # Asserting datatypes
    nhl_2018.W = nhl_2018.W.astype(float)
    nhl_2018.L = nhl_2018.L.astype(float)

    # Grouping by teams with same name and getting ther average W and L values
    nhl_2018 = nhl_2018.groupby(by='team', )['W', 'L'].mean()
    nhl_2018.reset_index(inplace=True)

    # Merging DataFrames
    cities.rename(columns={'NHL': 'team'}, inplace=True)
    merged = pd.merge(nhl_2018, cities, how='inner', on='team')

    # Creating Win/Loss ratio column
    merged['Win/Loss Ratio'] = merged.W / (merged.W + merged.L)

    # Passing in the numeric values of population_by_region and win_loss_by_region
    population_by_region = pd.to_numeric(merged['Population Estimate 2016'], errors='coerce')
    win_loss_by_region = pd.to_numeric(merged['Win/Loss Ratio'], errors='coerce')

    assert len(population_by_region) == len(win_loss_by_region), "Q1: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q1: There should be 28 teams being analysed for NHL"

    answer = stats.pearsonr(population_by_region, win_loss_by_region)[0]
    return answer

# %%
nhl_correlation()
# Out:
# <ipython-input-97-e313f2f86d00>:59: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   nhl_2018 = nhl_2018.groupby(by='team', )['W', 'L'].mean()
# 0.01230899645574427

# %% [markdown]
# ## Question Two

# %%
nba_df=pd.read_csv("assets/nba.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

# %%
cities['NBA']
# Out:
# 0            Knicks Nets
# 1        Lakers Clippers
# 2               Warriors
# 3          Bulls[note 9]
# 4              Mavericks
# 5       Wizards[note 11]
# 6                  76ers
# 7                Celtics
# 8           Timberwolves
# 9       Nuggets[note 17]
# 10                  Heat
# 11                  Suns
# 12      Pistons[note 21]
# 13      Raptors[note 23]
# 14               Rockets
# 15                 Hawks
# 16                     —
# 17             [note 27]
# 18    Cavaliers[note 31]
# 19             [note 33]
# 20             [note 36]
# 21             [note 38]
# 22             [note 42]
# 23             [note 47]
# 24      Hornets[note 49]
# 25       Pacers[note 51]
# 26                     —
# 27                 Bucks
# 28     Pelicans[note 55]
# 29             [note 58]
# 30                     —
# 31             [note 60]
# 32                 Magic
# 33         Trail Blazers
# 34                     —
# 35                     —
# 36                     —
# 37                     —
# 38                  Jazz
# 39                     —
# 40             [note 63]
# 41                 Spurs
# 42                 Kings
# 43                     —
# 44                     —
# 45      Thunder[note 68]
# 46             Grizzlies
# 47                     —
# 48                     —
# 49                     —
# 50                     —
# Name: NBA, dtype: object

# %%
nba_df
# Out:
#                           team   W   L                W/L%    GB   PS/G  \
# 0         Toronto Raptors* (1)  59  23                0.72     —  111.7
# 1          Boston Celtics* (2)  55  27  0.6709999999999999   4.0  104.0
# 2      Philadelphia 76ers* (3)  52  30               0.634   7.0  109.8
# 3     Cleveland Cavaliers* (4)  50  32                0.61   9.0  110.9
# 4          Indiana Pacers* (5)  48  34               0.585  11.0  105.6
# ..                         ...  ..  ..                 ...   ...    ...
# 157     San Antonio Spurs* (1)  62  20                .756     —  105.4
# 158       Houston Rockets* (4)  54  28                .659   8.0  107.7
# 159     Memphis Grizzlies* (7)  50  32                .610  12.0   96.1
# 160      Dallas Mavericks* (8)  49  33                .598  13.0  104.8
# 161  New Orleans Pelicans (12)  34  48                .415  28.0   99.7
#
#       PA/G    SRS  year League
# 0    103.9   7.29  2018    NBA
# 1    100.4   3.23  2018    NBA
# 2    105.3    4.3  2018    NBA
# 3    109.9   0.59  2018    NBA
# 4    104.2   1.18  2018    NBA
# ..     ...    ...   ...    ...
# 157   97.6   8.00  2014    NBA
# 158  103.1   5.06  2014    NBA
# 159   94.6   2.18  2014    NBA
# 160  102.4   2.91  2014    NBA
# 161  102.4  -1.98  2014    NBA
#
# [162 rows x 10 columns]

# %%
# Filtering data
nba_2018 = nba_df[nba_df.year == 2018]
nba_2018
# Out:
#                            team   W   L                 W/L%    GB   PS/G  \
# 0          Toronto Raptors* (1)  59  23                 0.72     —  111.7
# 1           Boston Celtics* (2)  55  27   0.6709999999999999   4.0  104.0
# 2       Philadelphia 76ers* (3)  52  30                0.634   7.0  109.8
# 3      Cleveland Cavaliers* (4)  50  32                 0.61   9.0  110.9
# 4           Indiana Pacers* (5)  48  34                0.585  11.0  105.6
# 5               Miami Heat* (6)  44  38                0.537  15.0  103.4
# 6          Milwaukee Bucks* (7)  44  38                0.537  15.0  106.5
# 7       Washington Wizards* (8)  43  39                0.524  16.0  106.6
# 8           Detroit Pistons (9)  39  43  0.47600000000000003  20.0  103.8
# 9        Charlotte Hornets (10)  36  46                0.439  23.0  108.2
# 10         New York Knicks (11)  29  53                0.354  30.0  104.5
# 11           Brooklyn Nets (12)  28  54                0.341  31.0  106.6
# 12           Chicago Bulls (13)  27  55  0.32899999999999996  32.0  102.9
# 13           Orlando Magic (14)  25  57                0.305  34.0  103.4
# 14           Atlanta Hawks (15)  24  58                0.293  35.0  103.4
# 15         Houston Rockets* (1)  65  17   0.7929999999999999     —  112.4
# 16   Golden State Warriors* (2)  58  24   0.7070000000000001   7.0  113.5
# 17  Portland Trail Blazers* (3)  49  33                0.598  16.0  105.6
# 18   Oklahoma City Thunder* (4)  48  34                0.585  17.0  107.9
# 19               Utah Jazz* (5)  48  34                0.585  17.0  104.1
# 20    New Orleans Pelicans* (6)  48  34                0.585  17.0  111.7
# 21       San Antonio Spurs* (7)  47  35                0.573  18.0  102.7
# 22  Minnesota Timberwolves* (8)  47  35                0.573  18.0  109.5
# 23           Denver Nuggets (9)  46  36                0.561  19.0  110.0
# 24    Los Angeles Clippers (10)  42  40                0.512  23.0  109.0
# 25      Los Angeles Lakers (11)  35  47  0.42700000000000005  30.0  108.1
# 26        Sacramento Kings (12)  27  55  0.32899999999999996  38.0   98.8
# 27        Dallas Mavericks (13)  24  58                0.293  41.0  102.3
# 28       Memphis Grizzlies (14)  22  60                0.268  43.0   99.3
# 29            Phoenix Suns (15)  21  61                0.256  44.0  103.9
#
#      PA/G    SRS  year League
# 0   103.9   7.29  2018    NBA
# 1   100.4   3.23  2018    NBA
# 2   105.3    4.3  2018    NBA
# 3   109.9   0.59  2018    NBA
# 4   104.2   1.18  2018    NBA
# 5   102.9   0.15  2018    NBA
# 6   106.8  -0.45  2018    NBA
# 7   106.0   0.53  2018    NBA
# 8   103.9  -0.26  2018    NBA
# 9   108.0   0.07  2018    NBA
# 10  108.0  -3.53  2018    NBA
# 11  110.3  -3.67  2018    NBA
# 12  110.0  -6.84  2018    NBA
# 13  108.2  -4.92  2018    NBA
# 14  108.8   -5.3  2018    NBA
# 15  103.9   8.21  2018    NBA
# 16  107.5   5.79  2018    NBA
# 17  103.0    2.6  2018    NBA
# 18  104.4   3.42  2018    NBA
# 19   99.8   4.47  2018    NBA
# 20  110.4   1.48  2018    NBA
# 21   99.8   2.89  2018    NBA
# 22  107.3   2.35  2018    NBA
# 23  108.5   1.57  2018    NBA
# 24  109.0   0.15  2018    NBA
# 25  109.6  -1.44  2018    NBA
# 26  105.8   -6.6  2018    NBA
# 27  105.4   -2.7  2018    NBA
# 28  105.5  -5.81  2018    NBA
# 29  113.3   -8.8  2018    NBA

# %%
# Cleaning teams' names in NBA DataFrame
def clean_team(item):
  if "(" in item:
    item = re.findall('^(.*?)\s\(\d+\)$', item)[0]
    if item[-1] == '*':
      item = item[:-1]
      return item
  return item

nba_2018['team'] = nba_2018.team.apply(clean_team)
nba_2018
# Out:
# <ipython-input-139-8f75a5d1dac4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_2018['team'] = nba_2018.team.apply(clean_team)
#                       team   W   L                 W/L%    GB   PS/G   PA/G  \
# 0          Toronto Raptors  59  23                 0.72     —  111.7  103.9
# 1           Boston Celtics  55  27   0.6709999999999999   4.0  104.0  100.4
# 2       Philadelphia 76ers  52  30                0.634   7.0  109.8  105.3
# 3      Cleveland Cavaliers  50  32                 0.61   9.0  110.9  109.9
# 4           Indiana Pacers  48  34                0.585  11.0  105.6  104.2
# 5               Miami Heat  44  38                0.537  15.0  103.4  102.9
# 6          Milwaukee Bucks  44  38                0.537  15.0  106.5  106.8
# 7       Washington Wizards  43  39                0.524  16.0  106.6  106.0
# 8          Detroit Pistons  39  43  0.47600000000000003  20.0  103.8  103.9
# 9        Charlotte Hornets  36  46                0.439  23.0  108.2  108.0
# 10         New York Knicks  29  53                0.354  30.0  104.5  108.0
# 11           Brooklyn Nets  28  54                0.341  31.0  106.6  110.3
# 12           Chicago Bulls  27  55  0.32899999999999996  32.0  102.9  110.0
# 13           Orlando Magic  25  57                0.305  34.0  103.4  108.2
# 14           Atlanta Hawks  24  58                0.293  35.0  103.4  108.8
# 15         Houston Rockets  65  17   0.7929999999999999     —  112.4  103.9
# 16   Golden State Warriors  58  24   0.7070000000000001   7.0  113.5  107.5
# 17  Portland Trail Blazers  49  33                0.598  16.0  105.6  103.0
# 18   Oklahoma City Thunder  48  34                0.585  17.0  107.9  104.4
# 19               Utah Jazz  48  34                0.585  17.0  104.1   99.8
# 20    New Orleans Pelicans  48  34                0.585  17.0  111.7  110.4
# 21       San Antonio Spurs  47  35                0.573  18.0  102.7   99.8
# 22  Minnesota Timberwolves  47  35                0.573  18.0  109.5  107.3
# 23          Denver Nuggets  46  36                0.561  19.0  110.0  108.5
# 24    Los Angeles Clippers  42  40                0.512  23.0  109.0  109.0
# 25      Los Angeles Lakers  35  47  0.42700000000000005  30.0  108.1  109.6
# 26        Sacramento Kings  27  55  0.32899999999999996  38.0   98.8  105.8
# 27        Dallas Mavericks  24  58                0.293  41.0  102.3  105.4
# 28       Memphis Grizzlies  22  60                0.268  43.0   99.3  105.5
# 29            Phoenix Suns  21  61                0.256  44.0  103.9  113.3
#
#       SRS  year League
# 0    7.29  2018    NBA
# 1    3.23  2018    NBA
# 2     4.3  2018    NBA
# 3    0.59  2018    NBA
# 4    1.18  2018    NBA
# 5    0.15  2018    NBA
# 6   -0.45  2018    NBA
# 7    0.53  2018    NBA
# 8   -0.26  2018    NBA
# 9    0.07  2018    NBA
# 10  -3.53  2018    NBA
# 11  -3.67  2018    NBA
# 12  -6.84  2018    NBA
# 13  -4.92  2018    NBA
# 14   -5.3  2018    NBA
# 15   8.21  2018    NBA
# 16   5.79  2018    NBA
# 17    2.6  2018    NBA
# 18   3.42  2018    NBA
# 19   4.47  2018    NBA
# 20   1.48  2018    NBA
# 21   2.89  2018    NBA
# 22   2.35  2018    NBA
# 23   1.57  2018    NBA
# 24   0.15  2018    NBA
# 25  -1.44  2018    NBA
# 26   -6.6  2018    NBA
# 27   -2.7  2018    NBA
# 28  -5.81  2018    NBA
# 29   -8.8  2018    NBA

# %%
# Cleaning NBA teams names in cities DataFrame
cities['NBA'] = cities.NBA.apply(lambda x: re.findall('([\w\s]*)\[', x)[0] if '[' in x else x)
cities['NBA']
# Out:
# 0         Knicks Nets
# 1     Lakers Clippers
# 2            Warriors
# 3               Bulls
# 4           Mavericks
# 5             Wizards
# 6               76ers
# 7             Celtics
# 8        Timberwolves
# 9             Nuggets
# 10               Heat
# 11               Suns
# 12            Pistons
# 13            Raptors
# 14            Rockets
# 15              Hawks
# 16                  —
# 17
# 18          Cavaliers
# 19
# 20
# 21
# 22
# 23
# 24            Hornets
# 25             Pacers
# 26                  —
# 27              Bucks
# 28           Pelicans
# 29
# 30                  —
# 31
# 32              Magic
# 33      Trail Blazers
# 34                  —
# 35                  —
# 36                  —
# 37                  —
# 38               Jazz
# 39                  —
# 40
# 41              Spurs
# 42              Kings
# 43                  —
# 44                  —
# 45            Thunder
# 46          Grizzlies
# 47                  —
# 48                  —
# 49                  —
# 50                  —
# Name: NBA, dtype: object

# %%
# Keeping only columns of interest
cities.rename(columns={'Population (2016 est.)[8]': 'Population Estimate 2016', 'NBA': 'team'}, inplace=True)
cities = cities[['Metropolitan area', 'Population Estimate 2016', 'team']]
cities
# Out:
#          Metropolitan area Population Estimate 2016             team
# 0            New York City                 20153634      Knicks Nets
# 1              Los Angeles                 13310447  Lakers Clippers
# 2   San Francisco Bay Area                  6657982         Warriors
# 3                  Chicago                  9512999            Bulls
# 4        Dallas–Fort Worth                  7233323        Mavericks
# 5         Washington, D.C.                  6131977          Wizards
# 6             Philadelphia                  6070500            76ers
# 7                   Boston                  4794447          Celtics
# 8   Minneapolis–Saint Paul                  3551036     Timberwolves
# 9                   Denver                  2853077          Nuggets
# 10   Miami–Fort Lauderdale                  6066387             Heat
# 11                 Phoenix                  4661537             Suns
# 12                 Detroit                  4297617          Pistons
# 13                 Toronto                  5928040          Raptors
# 14                 Houston                  6772470          Rockets
# 15                 Atlanta                  5789700            Hawks
# 16          Tampa Bay Area                  3032171                —
# 17              Pittsburgh                  2342299
# 18               Cleveland                  2055612        Cavaliers
# 19                 Seattle                  3798902
# 20              Cincinnati                  2165139
# 21             Kansas City                  2104509
# 22               St. Louis                  2807002
# 23               Baltimore                  2798886
# 24               Charlotte                  2474314          Hornets
# 25            Indianapolis                  2004230           Pacers
# 26               Nashville                  1865298                —
# 27               Milwaukee                  1572482            Bucks
# 28             New Orleans                  1268883         Pelicans
# 29                 Buffalo                  1132804
# 30                Montreal                  4098927                —
# 31               Vancouver                  2463431
# 32                 Orlando                  2441257            Magic
# 33                Portland                  2424955    Trail Blazers
# 34                Columbus                  2041520                —
# 35                 Calgary                  1392609                —
# 36                  Ottawa                  1323783                —
# 37                Edmonton                  1321426                —
# 38          Salt Lake City                  1186187             Jazz
# 39                Winnipeg                   778489                —
# 40               San Diego                  3317749
# 41             San Antonio                  2429609            Spurs
# 42              Sacramento                  2296418            Kings
# 43               Las Vegas                  2155664                —
# 44            Jacksonville                  1478212                —
# 45           Oklahoma City                  1373211          Thunder
# 46                 Memphis                  1342842        Grizzlies
# 47                 Raleigh                  1302946                —
# 48               Green Bay                   318236                —
# 49                Hamilton                   747545                —
# 50                  Regina                   236481                —

# %%
nba_2018 = nba_2018[['team', 'W', 'L']]
nba_2018
# Out:
#                       team   W   L
# 0          Toronto Raptors  59  23
# 1           Boston Celtics  55  27
# 2       Philadelphia 76ers  52  30
# 3      Cleveland Cavaliers  50  32
# 4           Indiana Pacers  48  34
# 5               Miami Heat  44  38
# 6          Milwaukee Bucks  44  38
# 7       Washington Wizards  43  39
# 8          Detroit Pistons  39  43
# 9        Charlotte Hornets  36  46
# 10         New York Knicks  29  53
# 11           Brooklyn Nets  28  54
# 12           Chicago Bulls  27  55
# 13           Orlando Magic  25  57
# 14           Atlanta Hawks  24  58
# 15         Houston Rockets  65  17
# 16   Golden State Warriors  58  24
# 17  Portland Trail Blazers  49  33
# 18   Oklahoma City Thunder  48  34
# 19               Utah Jazz  48  34
# 20    New Orleans Pelicans  48  34
# 21       San Antonio Spurs  47  35
# 22  Minnesota Timberwolves  47  35
# 23          Denver Nuggets  46  36
# 24    Los Angeles Clippers  42  40
# 25      Los Angeles Lakers  35  47
# 26        Sacramento Kings  27  55
# 27        Dallas Mavericks  24  58
# 28       Memphis Grizzlies  22  60
# 29            Phoenix Suns  21  61

# %%
# Separating team's names from cities' names and standardizing names
nba_2018['team'] = nba_2018.team.apply(lambda x: x.rsplit(None, 1)[-1])
nba_2018.loc[17, 'team'] = 'Trail Blazers'
nba_2018.loc[10, 'team'] = 'Knicks Nets'
nba_2018.loc[11, 'team'] = 'Knicks Nets'
nba_2018.loc[24, 'team'] = 'Lakers Clippers'
nba_2018.loc[25, 'team'] = 'Lakers Clippers'
nba_2018
# Out:
# <ipython-input-143-62d8d31c5d4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_2018['team'] = nba_2018.team.apply(lambda x: x.rsplit(None, 1)[-1])
#                team   W   L
# 0           Raptors  59  23
# 1           Celtics  55  27
# 2             76ers  52  30
# 3         Cavaliers  50  32
# 4            Pacers  48  34
# 5              Heat  44  38
# 6             Bucks  44  38
# 7           Wizards  43  39
# 8           Pistons  39  43
# 9           Hornets  36  46
# 10      Knicks Nets  29  53
# 11      Knicks Nets  28  54
# 12            Bulls  27  55
# 13            Magic  25  57
# 14            Hawks  24  58
# 15          Rockets  65  17
# 16         Warriors  58  24
# 17    Trail Blazers  49  33
# 18          Thunder  48  34
# 19             Jazz  48  34
# 20         Pelicans  48  34
# 21            Spurs  47  35
# 22     Timberwolves  47  35
# 23          Nuggets  46  36
# 24  Lakers Clippers  42  40
# 25  Lakers Clippers  35  47
# 26            Kings  27  55
# 27        Mavericks  24  58
# 28        Grizzlies  22  60
# 29             Suns  21  61

# %%
# Asserting datatypes
nba_2018.W = nba_2018.W.astype(float)
nba_2018.L = nba_2018.L.astype(float)

# Grouping rows with same name
nba_2018 = nba_2018.groupby(by='team')['W', 'L'].mean()
nba_2018.reset_index()
nba_2018
# Out:
# <ipython-input-144-427113e74ca3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_2018.W = nba_2018.W.astype(float)
# <ipython-input-144-427113e74ca3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_2018.L = nba_2018.L.astype(float)
# <ipython-input-144-427113e74ca3>:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   nba_2018 = nba_2018.groupby(by='team')['W', 'L'].mean()
#                     W     L
# team
# 76ers            52.0  30.0
# Bucks            44.0  38.0
# Bulls            27.0  55.0
# Cavaliers        50.0  32.0
# Celtics          55.0  27.0
# Grizzlies        22.0  60.0
# Hawks            24.0  58.0
# Heat             44.0  38.0
# Hornets          36.0  46.0
# Jazz             48.0  34.0
# Kings            27.0  55.0
# Knicks Nets      28.5  53.5
# Lakers Clippers  38.5  43.5
# Magic            25.0  57.0
# Mavericks        24.0  58.0
# Nuggets          46.0  36.0
# Pacers           48.0  34.0
# Pelicans         48.0  34.0
# Pistons          39.0  43.0
# Raptors          59.0  23.0
# Rockets          65.0  17.0
# Spurs            47.0  35.0
# Suns             21.0  61.0
# Thunder          48.0  34.0
# Timberwolves     47.0  35.0
# Trail Blazers    49.0  33.0
# Warriors         58.0  24.0
# Wizards          43.0  39.0

# %%
# Merging DataFrames
merged = pd.merge(nba_2018, cities, how='inner', on='team')
merged.W = merged.W.astype(float)
merged.L = merged.L.astype(float)
merged
# Out:
#                team     W     L       Metropolitan area  \
# 0             76ers  52.0  30.0            Philadelphia
# 1             Bucks  44.0  38.0               Milwaukee
# 2             Bulls  27.0  55.0                 Chicago
# 3         Cavaliers  50.0  32.0               Cleveland
# 4           Celtics  55.0  27.0                  Boston
# 5         Grizzlies  22.0  60.0                 Memphis
# 6             Hawks  24.0  58.0                 Atlanta
# 7              Heat  44.0  38.0   Miami–Fort Lauderdale
# 8           Hornets  36.0  46.0               Charlotte
# 9              Jazz  48.0  34.0          Salt Lake City
# 10            Kings  27.0  55.0              Sacramento
# 11      Knicks Nets  28.5  53.5           New York City
# 12  Lakers Clippers  38.5  43.5             Los Angeles
# 13            Magic  25.0  57.0                 Orlando
# 14        Mavericks  24.0  58.0       Dallas–Fort Worth
# 15          Nuggets  46.0  36.0                  Denver
# 16           Pacers  48.0  34.0            Indianapolis
# 17         Pelicans  48.0  34.0             New Orleans
# 18          Pistons  39.0  43.0                 Detroit
# 19          Raptors  59.0  23.0                 Toronto
# 20          Rockets  65.0  17.0                 Houston
# 21            Spurs  47.0  35.0             San Antonio
# 22             Suns  21.0  61.0                 Phoenix
# 23          Thunder  48.0  34.0           Oklahoma City
# 24     Timberwolves  47.0  35.0  Minneapolis–Saint Paul
# 25    Trail Blazers  49.0  33.0                Portland
# 26         Warriors  58.0  24.0  San Francisco Bay Area
# 27          Wizards  43.0  39.0        Washington, D.C.
#
#    Population Estimate 2016
# 0                   6070500
# 1                   1572482
# 2                   9512999
# 3                   2055612
# 4                   4794447
# 5                   1342842
# 6                   5789700
# 7                   6066387
# 8                   2474314
# 9                   1186187
# 10                  2296418
# 11                 20153634
# 12                 13310447
# 13                  2441257
# 14                  7233323
# 15                  2853077
# 16                  2004230
# 17                  1268883
# 18                  4297617
# 19                  5928040
# 20                  6772470
# 21                  2429609
# 22                  4661537
# 23                  1373211
# 24                  3551036
# 25                  2424955
# 26                  6657982
# 27                  6131977

# %%
# Creating Win/Loss Ratio column
merged['Win/Loss Ratio'] = merged.W/(merged.W + merged.L)
merged['Win/Loss Ratio']
# Out:
# 0     0.634146
# 1     0.536585
# 2     0.329268
# 3     0.609756
# 4     0.670732
# 5     0.268293
# 6     0.292683
# 7     0.536585
# 8     0.439024
# 9     0.585366
# 10    0.329268
# 11    0.347561
# 12    0.469512
# 13    0.304878
# 14    0.292683
# 15    0.560976
# 16    0.585366
# 17    0.585366
# 18    0.475610
# 19    0.719512
# 20    0.792683
# 21    0.573171
# 22    0.256098
# 23    0.585366
# 24    0.573171
# 25    0.597561
# 26    0.707317
# 27    0.524390
# Name: Win/Loss Ratio, dtype: float64

# %%
# Passing in values
population_by_region = pd.to_numeric(merged['Population Estimate 2016'], errors='coerce')
win_loss_by_region = pd.to_numeric(merged['Win/Loss Ratio'], errors='coerce')

answer = stats.pearsonr(population_by_region, win_loss_by_region)[0]
answer
# Out:
# -0.17657160252844614

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re


def nba_correlation():

    nba_df=pd.read_csv("assets/nba.csv")
    cities=pd.read_html("assets/wikipedia_data.html")[1]
    cities=cities.iloc[:-1,[0,3,5,6,7,8]]

    # Filtering data
    nba_2018 = nba_df[nba_df.year == 2018]

    # Cleaning teams' names in NBA DataFrame
    def clean_team(item):
      if "(" in item:
        item = re.findall('^(.*?)\s\(\d+\)$', item)[0]
        if item[-1] == '*':
          item = item[:-1]
          return item
      return item
    nba_2018['team'] = nba_2018.team.apply(clean_team)

    # Cleaning NBA teams names in cities DataFrame
    cities['NBA'] = cities.NBA.apply(lambda x: re.findall('([\w\s]*)\[', x)[0] if '[' in x else x)

    # Keeping only columns of interest
    cities.rename(columns={'Population (2016 est.)[8]': 'Population Estimate 2016', 'NBA': 'team'}, inplace=True)
    cities = cities[['Metropolitan area', 'Population Estimate 2016', 'team']]
    nba_2018 = nba_2018[['team', 'W', 'L']]

    # Separating team's names from cities' names and standardizing names
    nba_2018['team'] = nba_2018.team.apply(lambda x: x.rsplit(None, 1)[-1])
    nba_2018.loc[17, 'team'] = 'Trail Blazers'
    nba_2018.loc[10, 'team'] = 'Knicks Nets'
    nba_2018.loc[11, 'team'] = 'Knicks Nets'
    nba_2018.loc[24, 'team'] = 'Lakers Clippers'
    nba_2018.loc[25, 'team'] = 'Lakers Clippers'

    # Asserting datatypes
    nba_2018.W = nba_2018.W.astype(float)
    nba_2018.L = nba_2018.L.astype(float)

    # Grouping rows with same name
    nba_2018 = nba_2018.groupby(by='team')['W', 'L'].mean()
    nba_2018.reset_index()

    # Merging DataFrames
    merged = pd.merge(nba_2018, cities, how='inner', on='team')
    merged.W = merged.W.astype(float)
    merged.L = merged.L.astype(float)

    # Creating Win/Loss Ratio column
    merged['Win/Loss Ratio'] = merged.W/(merged.W + merged.L)

    # Passing in values
    population_by_region = pd.to_numeric(merged['Population Estimate 2016'], errors='coerce')
    win_loss_by_region = pd.to_numeric(merged['Win/Loss Ratio'], errors='coerce')

    assert len(population_by_region) == len(win_loss_by_region), "Q2: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q2: There should be 28 teams being analysed for NBA"

    answer = stats.pearsonr(population_by_region, win_loss_by_region)[0]
    answer

    return answer

nba_correlation()
# Out:
# <ipython-input-148-76a2aa76d414>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_2018['team'] = nba_2018.team.apply(clean_team)
# <ipython-input-148-76a2aa76d414>:47: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   nba_2018 = nba_2018.groupby(by='team')['W', 'L'].mean()
# -0.17657160252844614
